# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv("gen/results.csv", index_col=0)
fig = px.line(df)
fig.update_layout(height=600)
fig.show()
# Out:
# <div>                            <div id="0133d602-ba8e-416a-90a5-2aee3830dd72" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0133d602-ba8e-416a-90a5-2aee3830dd72")) {                    Plotly.newPlot(                        "0133d602-ba8e-416a-90a5-2aee3830dd72",                        [{"hovertemplate":"variable=numpy\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"numpy","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"numpy","showlegend":true,"x":["positive_Int8_1","positive_Int8_25","positive_Int8_250000","positive_Int16_1","positive_Int16_25","positive_Int16_250000","positive_Int32_1","positive_Int32_25","positive_Int32_250000","positive_Int
# ...
