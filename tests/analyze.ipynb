# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv("gen/results.csv", index_col=0)
fig = px.bar(df)
fig.update_layout(height=600)
fig.show()
# Out:
# <div>                            <div id="aead983c-8e70-40b7-be77-fcc50b4d0ced" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aead983c-8e70-40b7-be77-fcc50b4d0ced")) {                    Plotly.newPlot(                        "aead983c-8e70-40b7-be77-fcc50b4d0ced",                        [{"alignmentgroup":"True","hovertemplate":"variable=numpy\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"numpy","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"numpy","offsetgroup":"numpy","orientation":"v","showlegend":true,"textposition":"auto","x":["square_Int8_20","square_Int8_1000","square_Int8_10000","square_Int16_20","square_Int16_1000","square_Int16_10000","square_Int32_20","square_Int32_
# ...
